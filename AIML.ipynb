# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankitasahoo2003/2121206049_ECE/blob/main/AIML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('HELLO ABIT', end=' ')
print('DEPT.of ECE')
# Out:
# HELLO ABIT DEPT.of ECE

# %%
# Using of sep=''in print().
a=7
b=1
c=2023
print(a,b,c, sep='-')
# Out:
# 7-1-2023

# %%
print('HELLO ANKITA')
# Out:
# HELLO ANKITA
